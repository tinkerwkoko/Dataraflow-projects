# %% [markdown]
# # Course Overview and Software Installations

# %% [markdown]
# ## Introduction
#
# Welcome to the **DataraFlow** **Internship**
#
# This program runs for twenty-four weeks (approximately 6 months) with an expected commitment of around twelve hours of study per week. You are required to progress through the course content weekly.
#
# If you have extra time or complete your weekly tasks ahead of schedule, we encourage you to deepen your understanding by researching topics you’ve learned and challenging yourself with self-assigned projects.
#
# Throughout the course, you will learn to write your own programs—one line of code at a time. You’ll discover how to access open datasets, clean and analyze them, and create compelling visualizations. You will also gain the skills to document and share your analyses, either privately or with the public.
#
#
# This course has been written to show how a little bit of code can go a long way in making sense of the increasingly vast amounts of open data available online. If you’re used to the manual approach of copying and pasting formulas in spreadsheets, you’ll see that writing a few lines of code to manipulate data can be quicker, less error-prone, and more powerful.
#
# You will write code in a programming language called Python, named after the comedy group Monty Python. Python is very popular for teaching programming, but is also widely used in professional software development. We will be making use of Jupyter Notebook and Jupiter Lab which is a Development Environment (like a program), Jupyter which allows you to write notebooks that include Python code. Jupyter is used by many scientists and data analysts as part of their workflow. Although you will use Python and Jupyter at a basic level, you will be learning tools used by the pros. Python, Jupyter and other software you will need to take part in the course are included in the Anaconda distribution (like a package). You’ll have an opportunity to download the software in the next step.
#
# For now, think about your goals are for taking this course. Do you have any previous coding or data analysis experience, e.g. with spreadsheets? Perhaps you want to find more efficient ways of working with data, or perhaps you’re intrigued by the idea of what code is and how it can possibly help you work with data.
#
# We hope you enjoy the process!

# %% [markdown]
# ## What is Data Science(DS)
#
# Data science is an inter-disciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from many structural and unstructured data. Data science is related to data mining, machine learning and big data.
#
# Data science is a `"concept to unify statistics, data analysis, machine learning, domain knowledge and their related methods"` in order to "understand and analyze actual phenomena" with data. It uses techniques and theories drawn from many fields within the context of `mathematics, statistics, computer science, domain knowledge and information science`. Turing award winner Jim Gray imagined data science as a "fourth paradigm" of science `(empirical, theoretical, computational and now data-driven)` and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.
#
# Source [wikipedia](https://en.wikipedia.org/wiki/Data_science#:~:text=Data%20science%20is%20an%20inter,machine%20learning%20and%20big%20data.)
#
# What is data science? [Interesting Illustration](https://www.youtube.com/watch?v=xC-c7E5PK0Y)

# %% [markdown]
# ![freesnippingtool.com_capture_20200818004604.png](attachment:freesnippingtool.com_capture_20200818004604.png)

# %% [markdown]
# ## Data Science Tools
# Data scientists should know and master many tools.
#
# **Programming languages: Python and R**
#
# The two most popular programming languages for data science work are Python and R. Both have machine learning libraries, visualization, and data manipulation and analysis packages that are essential for every data scientist. Both are open source and were developed in the early 1990s: Python as a general-purpose programming language, and R for statistical analysis. They have a huge community that supports the growth of these tools to meet the rapid expansion of data science.
#
#
# **Software Tools**
#
# - **Anaconda** is a free and open-source distribution of the Python and R programming languages for scientific computing (data science, machine learning applications, large-scale data processing, predictive analytics, etc.), that aims to simplify package management and deployment
#
#
# - **KoBoToolbox** is a suite of tools for field data collection for use in challenging environments.
#
#
# - **SPSS** is the abbreviation of Statistical Package for Social Sciences and it is used by researchers to perform statistical analysis. As the name suggests, SPSS statistics software is used to perform only statistical operations.

# %% [markdown]
# **Software Installations**
#
# - Install Anaconda Navigator (Click under Python 3.X Version, Click "Download"): [Click to download](https://www.anaconda.com/distribution/)
#
# - Install Tableau Public (Type your email and click "Download the App"): [Click to download](https://public.tableau.com/en-us/s/)

# %% [markdown]
# ## Fundamental role of Data Scientists
#
# "The whole point of data scientists is to fundamentally ask big questions of the data you have". "Your job is to think about gaps in the data, to question it, and how to combine it in different ways to create value that someone else can then analyze. Data scientists usually have math, tech and stats skills, but the X-factor for data scientists is intellectual curiosity – to have that vision of what the data might tell me."
#
# **A data scientist has the following attributes:**
#
# - A curious person who can create business value from data.
# - Someone with a skill set that includes mathematics, technology, programming, and business acumen.

# %% [markdown]
# **Assignment**
#
# - Download all softwares and share screenshot of successful installation in the onboarding channel
# - Share your feedback on on the channel about the youtube video you watched.
# - Move to the next section

# %% [markdown]
# # **Machine Learning: Overview, Role, and Importance**
#
# ## **What is Machine Learning?**
#
# Machine Learning (ML) is a branch of **artificial intelligence (AI)** that enables computers to learn and improve from experience **without being explicitly programmed**.
# Instead of following fixed, hardcoded rules, an ML system uses **data** to recognize patterns, make decisions, and improve its performance over time.
#
# > **Simple analogy:** Just like humans learn from examples and experiences, machines learn from **data**.
#
#
# ## **Fundamental Role of Machine Learning**
#
# The core role of ML is to:
#
# 1. **Learn from Data**
#
#    * Identify patterns, relationships, and structures within data.
#
# 2. **Make Predictions or Decisions**
#
#    * Use what has been learned to forecast outcomes or take actions without direct human intervention.
#
# 3. **Improve Over Time**
#
#    * Adapt and refine models as new data becomes available, increasing accuracy and efficiency.
#
# 4. **Automate Complex Tasks**
#
#    * Handle processes that are too time-consuming, repetitive, or complex for manual programming.
#
#
# ## **Importance of Machine Learning**
#
# 1. **Data-Driven Decision Making**
#
#    * ML transforms raw data into actionable insights, enabling smarter business and policy decisions.
#
# 2. **Handling Big Data**
#
#    * ML can process massive datasets faster and more accurately than humans.
#
# 3. **Personalization**
#
#    * From product recommendations to tailored healthcare treatments, ML powers personalized experiences.
#
# 4. **Innovation Driver**
#
#    * Enables new technologies such as self-driving cars, voice assistants, fraud detection systems, and generative AI.
#
# 5. **Continuous Improvement**
#
#    * Models evolve with new data, keeping solutions relevant and effective in changing environments.
#
#
# ✅ **In short:** Machine Learning is about making computers *smarter with data*. Its role is to learn, adapt, and make decisions, and its importance lies in powering innovation, efficiency, and intelligent automation across industries.
#
# ---

# %% [markdown]
# # Watch the Setup & Installation video here: https://youtu.be/FxbRXcZ2W1I
